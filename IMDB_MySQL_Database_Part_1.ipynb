# %% [markdown]
# # IMDB MySQL Database Part One
# * James Belk
# * 3/22/2023

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
# basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
# akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
# ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv('Data/title_basics.csv.gz', low_memory = False)

# %%
akas = pd.read_csv('Data/title_akas.csv.gz', low_memory=False)

# %%
ratings = pd.read_csv('Data/title_ratings.csv.gz', low_memory=False)

# %% [markdown]
# ### Save Datasets to 'Data' Folder

# %%
basics.to_csv('Data/title_basics.csv.gz',compression='gzip',index=False)

# %%
akas.to_csv('Data/title_akas.csv.gz', compression='gzip', index = False)

# %%
ratings.to_csv('Data/title_ratings.csv.gz', compression='gzip', index = False)

# %% [markdown]
# # Clean Data

# %% [markdown]
# ## Title Basics

# %%
display(basics.head())
display(basics.info())
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000002     short                       Le clown et ses chiens
# 1  tt0000005     short                             Blacksmith Scene
# 2  tt0000006     short                            Chinese Opium Den
# 3  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 4  tt0000009     movie                                   Miss Jerry
#
#                                  originalTitle  isAdult  startYear  endYear  \
# 0                       Le clown et ses chiens        0     1892.0      NaN
# 1                             Blacksmith Scene        0     1893.0      NaN
# 2                            Chinese Opium Den        0     1894.0      NaN
# 3  Corbett and Courtney Before the Kinetograph        0     1894.0      NaN
# 4                                   Miss Jerry        0     1894.0      NaN
#
#    runtimeMinutes           genres
# 0               5  Animation,Short
# 1               1     Comedy,Short
# 2               1            Short
# 3               1      Short,Sport
# 4              45          Romance
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714643 entries, 0 to 714642
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          714643 non-null  object
#  1   titleType       714643 non-null  object
#  2   primaryTitle    714643 non-null  object
#  3   originalTitle   714643 non-null  object
#  4   isAdult         714643 non-null  int64
#  5   startYear       707871 non-null  float64
#  6   endYear         17538 non-null   float64
#  7   runtimeMinutes  714643 non-null  int64
#  8   genres          714643 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 49.1+ MB
# None

# %% [markdown]
# ### Replace '\N'

# %%
basics = basics.replace({'\\N': np.nan})
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %% [markdown]
# ### Eliminate Movies That Are Null For 'runtimeMinutes'

# %%
runtime_drop = basics.dropna(subset=['runtimeMinutes'], inplace = True)

# %% [markdown]
# ### Eliminate Movies That Are Null For Genre

# %%
genre_null = basics.dropna(subset=['genres'], inplace = True)

# %% [markdown]
# ### Keep Only 'titleType' Movie

# %%
movie_type = basics['titleType']=='Movie'

# %% [markdown]
# ### Keep 'startYear' 2000-2002

# %%
date_range = basics['startYear']==('2000', '2001', '2002')

# %% [markdown]
# ### Eliminate Movies That Include 'Documentary' in Genre

# %%
is_documentary = basics['genres'].str.contains('documentary', case = False)
basics = basics[~is_documentary]

# %% [markdown]
# ### Keep Only US Movies

# %%
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 1           True
# 2          False
# 3          False
# 4           True
# 5           True
#            ...
# 9710907    False
# 9710940    False
# 9710975    False
# 9710982    False
# 9710983    False
# Name: tconst, Length: 2375360, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType                                 primaryTitle  \
# 1        tt0000002     short                       Le clown et ses chiens
# 4        tt0000005     short                             Blacksmith Scene
# 5        tt0000006     short                            Chinese Opium Den
# 6        tt0000007     short  Corbett and Courtney Before the Kinetograph
# 8        tt0000009     movie                                   Miss Jerry
# ...            ...       ...                                          ...
# 9710677  tt9916214     short                              Drown the Clown
# 9710697  tt9916254     video                         Big Tit Cream Pie 32
# 9710743  tt9916348     video                        Ancient World Exposed
# 9710750  tt9916362     movie                                        Coven
# 9710845  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
#
#                                        originalTitle isAdult startYear  \
# 1                             Le clown et ses chiens       0      1892
# 4                                   Blacksmith Scene       0      1893
# 5                                  Chinese Opium Den       0      1894
# 6        Corbett and Courtney Before the Kinetograph       0      1894
# 8                                         Miss Jerry       0      1894
# ...                                              ...     ...       ...
# 9710677                              Drown the Clown       0      2019
# 9710697                         Big Tit Cream Pie 32       1      2015
# 9710743                        Ancient World Exposed       0      2019
# 9710750                                     Akelarre       0      2020
# 9710845    March of Dimes Presents: Once Upon a Dime       0      1963
#
#         endYear runtimeMinutes           genres
# 1           NaN              5  Animation,Short
# 4           NaN              1     Comedy,Short
# 5           NaN              1            Short
# 6           NaN              1      Short,Sport
# 8           NaN             45          Romance
# ...         ...            ...              ...
# 9710677     NaN              8      Drama,Short
# 9710697     NaN            226            Adult
# 9710743     NaN             67          History
# 9710750     NaN             92    Drama,History
# 9710845     NaN             58           Family
#
# [714643 rows x 9 columns]

# %%
basics.info()

# %% [markdown]
# ## AKAs

# %%
display(akas.head())
akas.info()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35330391 entries, 0 to 35330390
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ GB

# %%
akas['region'].isin(['US']).any()
# Out:
# True

# %%
usa_filter = akas['region']=='US'
akas = akas.loc[usa_filter, :]
akas['region'].value_counts(dropna = False)
# Out:
# US    1424064
# Name: region, dtype: int64

# %%
akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US       \N  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 33  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#                attributes isOriginalTitle
# 5                      \N               0
# 14  literal English title               0
# 33                     \N               0
# 36                     \N               0
# 41                     \N               0

# %%
akas = akas.replace({'\\N': np.nan})
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35329917  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35329987  tt9916620         1                          The Copeland Case
# 35330076  tt9916702         1              Loving London: The Playground
# 35330119  tt9916756         1                   Pretty Pretty Black Girl
# 35330135  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 35329917     US      NaN  imdbDisplay                    NaN               0
# 35329987     US      NaN  imdbDisplay                    NaN               0
# 35330076     US      NaN          NaN                    NaN               0
# 35330119     US      NaN  imdbDisplay                    NaN               0
# 35330135     US      NaN  imdbDisplay                    NaN               0
#
# [1424064 rows x 8 columns]

# %%
akas.info()

# %% [markdown]
# ## Ratings

# %%
display(ratings.head())
ratings.info()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1961
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1799
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2600
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292598 entries, 0 to 1292597
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1292598 non-null  object
#  1   averageRating  1292598 non-null  float64
#  2   numVotes       1292598 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 29.6+ MB

# %%
usa = ratings['tconst'].isin(akas['titleId'])
usa
# Out:
# 0          True
# 1          True
# 4          True
# 5          True
# 6          True
#            ...
# 1292563    True
# 1292564    True
# 1292571    True
# 1292572    True
# 1292576    True
# Name: tconst, Length: 492984, dtype: bool

# %%
ratings = ratings[usa]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1961
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2600
# 5        tt0000006            5.1       178
# 6        tt0000007            5.4       817
# ...            ...            ...       ...
# 1292563  tt9916200            8.2       224
# 1292564  tt9916204            8.2       256
# 1292571  tt9916348            8.3        18
# 1292572  tt9916362            6.4      5242
# 1292576  tt9916428            3.8        14
#
# [492984 rows x 3 columns]

# %%
ratings = ratings.replace({'\\N': np.nan})
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1961
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2600
# 5        tt0000006            5.1       178
# 6        tt0000007            5.4       817
# ...            ...            ...       ...
# 1292563  tt9916200            8.2       224
# 1292564  tt9916204            8.2       256
# 1292571  tt9916348            8.3        18
# 1292572  tt9916362            6.4      5242
# 1292576  tt9916428            3.8        14
#
# [492984 rows x 3 columns]

# %%
ratings.info()
