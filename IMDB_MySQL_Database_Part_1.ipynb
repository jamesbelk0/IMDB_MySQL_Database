# %% [markdown]
# # IMDB MySQL Database Part One
# * James Belk
# * 3/22/2023

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
# basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
# akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
# ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv('Data/title_basics.csv.gz', low_memory = False)

# %%
akas = pd.read_csv('Data/title_akas.csv.gz', low_memory=False)

# %%
ratings = pd.read_csv('Data/title_ratings.csv.gz', low_memory=False)

# %% [markdown]
# ### Save Datasets to 'Data' Folder

# %%
basics.to_csv('Data/title_basics.csv.gz',compression='gzip',index=False)

# %%
akas.to_csv('Data/title_akas.csv.gz', compression='gzip', index = False)

# %%
ratings.to_csv('Data/title_ratings.csv.gz', compression='gzip', index = False)

# %% [markdown]
# # Clean Data

# %% [markdown]
# ## Title Basics

# %%
display(basics.head())
display(basics.info())
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000002     short                       Le clown et ses chiens
# 1  tt0000005     short                             Blacksmith Scene
# 2  tt0000006     short                            Chinese Opium Den
# 3  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 4  tt0000009     movie                                   Miss Jerry
#
#                                  originalTitle  isAdult  startYear  endYear  \
# 0                       Le clown et ses chiens        0     1892.0      NaN
# 1                             Blacksmith Scene        0     1893.0      NaN
# 2                            Chinese Opium Den        0     1894.0      NaN
# 3  Corbett and Courtney Before the Kinetograph        0     1894.0      NaN
# 4                                   Miss Jerry        0     1894.0      NaN
#
#    runtimeMinutes           genres
# 0               5  Animation,Short
# ...

# %% [markdown]
# ### Replace '\N'

# %%
basics = basics.replace({'\\N': np.nan})
basics.head()
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000002     short                       Le clown et ses chiens
# 1  tt0000005     short                             Blacksmith Scene
# 2  tt0000006     short                            Chinese Opium Den
# 3  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 4  tt0000009     movie                                   Miss Jerry
#
#                                  originalTitle  isAdult  startYear  endYear  \
# 0                       Le clown et ses chiens        0     1892.0      NaN
# 1                             Blacksmith Scene        0     1893.0      NaN
# 2                            Chinese Opium Den        0     1894.0      NaN
# 3  Corbett and Courtney Before the Kinetograph        0     1894.0      NaN
# 4                                   Miss Jerry        0     1894.0      NaN
#
#    runtimeMinutes           genres
# 0               5  Animation,Short
# ...

# %% [markdown]
# ### Eliminate Movies That Are Null For 'runtimeMinutes'

# %%
runtime_drop = basics.dropna(subset=['runtimeMinutes'], inplace = True)

# %% [markdown]
# ### Eliminate Movies That Are Null For Genre

# %%
genre_null = basics.dropna(subset=['genres'], inplace = True)

# %% [markdown]
# ### Keep Only 'titleType' Movie

# %%
movie_type = basics['titleType']=='movie'
basics = basics.loc[movie_type,:]
basics['titleType'].value_counts(dropna = False)
basics.head()
# Out:
#         tconst titleType                    primaryTitle  \
# 4    tt0000009     movie                      Miss Jerry
# 105  tt0000574     movie     The Story of the Kelly Gang
# 111  tt0000591     movie                The Prodigal Son
# 143  tt0000679     movie  The Fairylogue and Radio-Plays
# 411  tt0001285     movie               The Life of Moses
#
#                       originalTitle  isAdult  startYear  endYear  \
# 4                        Miss Jerry        0     1894.0      NaN
# 105     The Story of the Kelly Gang        0     1906.0      NaN
# 111               L'enfant prodigue        0     1907.0      NaN
# 143  The Fairylogue and Radio-Plays        0     1908.0      NaN
# 411               The Life of Moses        0     1909.0      NaN
#
#      runtimeMinutes                      genres
# 4                45                     Romance
# 105              70  Action,Adventure,Biography
# 111              90                       Drama
# ...

# %% [markdown]
# ### Keep 'startYear' 2000-2002

# %%
date_range = (basics['startYear']>=2000)&(basics['startYear']<2002)
basics = basics.loc[date_range,:]
basics.head()
#basics['startYear'].value_counts(dropna=False)
# Out:
#           tconst titleType      primaryTitle     originalTitle  isAdult  \
# 21232  tt0035423     movie    Kate & Leopold    Kate & Leopold        0
# 62320  tt0113026     movie   The Fantasticks   The Fantasticks        0
# 62354  tt0113092     movie     For the Cause     For the Cause        0
# 62975  tt0114447     movie  The Silent Force  The Silent Force        0
# 63615  tt0115937     movie       Consequence       Consequence        0
#
#        startYear  endYear  runtimeMinutes                  genres
# 21232     2001.0      NaN             118  Comedy,Fantasy,Romance
# 62320     2000.0      NaN              86         Musical,Romance
# 62354     2000.0      NaN             100  Action,Adventure,Drama
# 62975     2001.0      NaN              90                  Action
# 63615     2000.0      NaN              91                   Drama

# %% [markdown]
# ### Eliminate Movies That Include 'Documentary' in Genre

# %%
is_documentary = basics['genres'].str.contains('documentary', case = False)
basics = basics[~is_documentary]
basics
# Out:
#            tconst titleType         primaryTitle        originalTitle  \
# 21232   tt0035423     movie       Kate & Leopold       Kate & Leopold
# 62320   tt0113026     movie      The Fantasticks      The Fantasticks
# 62354   tt0113092     movie        For the Cause        For the Cause
# 62975   tt0114447     movie     The Silent Force     The Silent Force
# 63615   tt0115937     movie          Consequence          Consequence
# ...           ...       ...                  ...                  ...
# 701472  tt9212730     movie        Yakuza Zombie         Zonbi gokudo
# 701839  tt9228234     movie      The Narc Enigma      The Narc Enigma
# 705657  tt9412476     movie  Contratiempo Mortal  Contratiempo Mortal
# 707918  tt9555974     movie       Haunted School         Gui xue xiao
# 708403  tt9578462     movie           Crying Sky   Ku qi de tian kong
#
#         isAdult  startYear  endYear  runtimeMinutes                  genres
# ...

# %% [markdown]
# ### Keep Only US Movies

# %%
basics = basics.loc[movie_type, ]

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2994 entries, 21232 to 708403
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          2994 non-null   object
#  1   titleType       2994 non-null   object
#  2   primaryTitle    2994 non-null   object
#  3   originalTitle   2994 non-null   object
#  4   isAdult         2994 non-null   int64
#  5   startYear       2994 non-null   float64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  2994 non-null   int64
#  8   genres          2994 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 233.9+ KB

# %% [markdown]
# ## AKAs

# %%
display(akas.head())
akas.info()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1424064 entries, 0 to 1424063
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1424064 non-null  object
# ...

# %%
akas['region'].isin(['US']).any()
# Out:
# True

# %%
usa_filter = akas['region']=='US'
akas = akas.loc[usa_filter, :]
akas['region'].value_counts(dropna = False)
# Out:
# US    1424064
# Name: region, dtype: int64

# %%
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
akas = akas.replace({'\\N': np.nan})
akas
# Out:
#            titleId  ordering                                      title  \
# 0        tt0000001         6                                 Carmencita
# 1        tt0000002         7                     The Clown and His Dogs
# 2        tt0000005        10                           Blacksmith Scene
# 3        tt0000005         1                        Blacksmithing Scene
# 4        tt0000005         6                        Blacksmith Scene #1
# ...            ...       ...                                        ...
# 1424059  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 1424060  tt9916620         1                          The Copeland Case
# 1424061  tt9916702         1              Loving London: The Playground
# 1424062  tt9916756         1                   Pretty Pretty Black Girl
# 1424063  tt9916764         1                                         38
#
#         region language        types             attributes  isOriginalTitle
# ...

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1424064 entries, 0 to 1424063
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1424064 non-null  object
#  1   ordering         1424064 non-null  int64
#  2   title            1424064 non-null  object
#  3   region           1424064 non-null  object
#  4   language         3866 non-null     object
#  5   types            976227 non-null   object
#  6   attributes       46241 non-null    object
#  7   isOriginalTitle  1422719 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 97.8+ MB

# %% [markdown]
# ## Ratings

# %%
display(ratings.head())
ratings.info()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1961
# 1  tt0000002            5.8       263
# 2  tt0000005            6.2      2600
# 3  tt0000006            5.1       178
# 4  tt0000007            5.4       817
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492984 entries, 0 to 492983
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         492984 non-null  object
#  1   averageRating  492984 non-null  float64
#  2   numVotes       492984 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.3+ MB

# %%
usa = ratings['tconst'].isin(akas['titleId'])
usa
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 492979    True
# 492980    True
# 492981    True
# 492982    True
# 492983    True
# Name: tconst, Length: 492984, dtype: bool

# %%
ratings = ratings[usa].value_counts(dropna = False)
ratings
# Out:
# tconst      averageRating  numVotes
# tt0000001   5.7            1961        1
# tt18291774  5.8            21          1
# tt1830316   7.8            15          1
# tt1830312   8.4            77          1
# tt1830307   8.2            16          1
#                                       ..
# tt0588607   8.2            32          1
# tt0588606   8.3            34          1
# tt0588605   8.2            31          1
# tt0588604   8.0            44          1
# tt9916428   3.8            14          1
# Length: 492984, dtype: int64

# %%
ratings = ratings.replace({'\\N': np.nan})
ratings
# Out:
# tconst      averageRating  numVotes
# tt0000001   5.7            1961        1
# tt18291774  5.8            21          1
# tt1830316   7.8            15          1
# tt1830312   8.4            77          1
# tt1830307   8.2            16          1
#                                       ..
# tt0588607   8.2            32          1
# tt0588606   8.3            34          1
# tt0588605   8.2            31          1
# tt0588604   8.0            44          1
# tt9916428   3.8            14          1
# Length: 492984, dtype: int64

# %%
ratings.info()
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex: 492984 entries, ('tt0000001', 5.7, 1961) to ('tt9916428', 3.8, 14)
# Series name: None
# Non-Null Count   Dtype
# --------------   -----
# 492984 non-null  int64
# dtypes: int64(1)
# memory usage: 27.1+ MB

# %%
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 21232     True
# 62320     True
# 62354     True
# 62975     True
# 63615     True
#           ...
# 701472    True
# 701839    True
# 705657    True
# 707918    True
# 708403    True
# Name: tconst, Length: 2994, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#            tconst titleType         primaryTitle        originalTitle  \
# 21232   tt0035423     movie       Kate & Leopold       Kate & Leopold
# 62320   tt0113026     movie      The Fantasticks      The Fantasticks
# 62354   tt0113092     movie        For the Cause        For the Cause
# 62975   tt0114447     movie     The Silent Force     The Silent Force
# 63615   tt0115937     movie          Consequence          Consequence
# ...           ...       ...                  ...                  ...
# 701472  tt9212730     movie        Yakuza Zombie         Zonbi gokudo
# 701839  tt9228234     movie      The Narc Enigma      The Narc Enigma
# 705657  tt9412476     movie  Contratiempo Mortal  Contratiempo Mortal
# 707918  tt9555974     movie       Haunted School         Gui xue xiao
# 708403  tt9578462     movie           Crying Sky   Ku qi de tian kong
#
#         isAdult  startYear  endYear  runtimeMinutes                  genres
# ...

# %% [markdown]
# # Compressed Files

# %%
final_basics = basics.to_csv(f'Data/final_basics.csv.gz', compression='gzip', index=False)
final_akas = akas.to_csv(f'Data/final_akas.csv.gz', compression='gzip', index=False)
final_ratings = ratings.to_csv(f'Data/final_ratings.csv.gz', compression='gzip', index=False)
